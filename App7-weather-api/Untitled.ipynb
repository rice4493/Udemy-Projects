# %% [markdown]
# # load the dataframe

# %%
import pandas as pd

# %%
df = pd.read_csv("data_small/TG_STAID000001.txt", skiprows= 20, parse_dates= ["    DATE"])

# %%
df
# Out:
#        STAID   SOUID       DATE     TG   Q_TG
# 0          1   35381 1860-01-01     21      0
# 1          1   35381 1860-01-02     46      0
# 2          1   35381 1860-01-03     31      0
# 3          1   35381 1860-01-04     37      0
# 4          1   35381 1860-01-05     31      0
# ...      ...     ...        ...    ...    ...
# 59316      1   35381 2022-05-27  -9999      9
# 59317      1   35381 2022-05-28  -9999      9
# 59318      1   35381 2022-05-29  -9999      9
# 59319      1   35381 2022-05-30  -9999      9
# 59320      1   35381 2022-05-31  -9999      9
#
# [59321 rows x 5 columns]

# %% [markdown]
# # show certain rows

# %%
df[10:20]
# Out:
#     STAID   SOUID       DATE     TG   Q_TG
# 10      1   35381 1860-01-11     -5      0
# 11      1   35381 1860-01-12    -18      0
# 12      1   35381 1860-01-13    -27      0
# 13      1   35381 1860-01-14    -26      0
# 14      1   35381 1860-01-15    -37      0
# 15      1   35381 1860-01-16     -9      0
# 16      1   35381 1860-01-17      7      0
# 17      1   35381 1860-01-18     -6      0
# 18      1   35381 1860-01-19    -16      0
# 19      1   35381 1860-01-20    -19      0

# %% [markdown]
# # show certain columns

# %%
df["   TG"]
# Out:
# 0          21
# 1          46
# 2          31
# 3          37
# 4          31
#          ...
# 59316   -9999
# 59317   -9999
# 59318   -9999
# 59319   -9999
# 59320   -9999
# Name:    TG, Length: 59321, dtype: int64

# %%
df["   TG"], ["   DATE"]
# Out:
# (0          21
#  1          46
#  2          31
#  3          37
#  4          31
#           ...
#  59316   -9999
#  59317   -9999
#  59318   -9999
#  59319   -9999
#  59320   -9999
#  Name:    TG, Length: 59321, dtype: int64,
#  ['   DATE'])

# %% [markdown]
# # simple statistics and filtering

# %%
df["   TG"].mean()
# Out:
# -991.1500649011311

# %%
df.loc[df["   TG"] != -9999]
# Out:
#        STAID   SOUID       DATE     TG   Q_TG
# 0          1   35381 1860-01-01     21      0
# 1          1   35381 1860-01-02     46      0
# 2          1   35381 1860-01-03     31      0
# 3          1   35381 1860-01-04     37      0
# 4          1   35381 1860-01-05     31      0
# ...      ...     ...        ...    ...    ...
# 53655      1   35381 2006-11-26     80      0
# 53656      1   35381 2006-11-27     70      0
# 53657      1   35381 2006-11-28     71      0
# 53658      1   35381 2006-11-29     63      0
# 53659      1   35381 2006-11-30     84      0
#
# [53103 rows x 5 columns]

# %%
df.loc[df["   TG"] != -9999]["   TG"].mean()/10
# Out:
# 6.360787526128467

# %%
df.loc[df["   TG"] != -9999]["   TG"].max()/10
# Out:
# 26.2

# %%
df.loc[df["   TG"] != -9999]["   TG"].min()/10
# Out:
# -28.8

# %%
df.loc[df["   TG"] != -9999]["   TG"].hist()
# Out:
# <Axes: >

# %% [markdown]
# # get certain cells

# %%
df.loc[df["   DATE"]=="1860-01-05"]["   TG"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/PycharmProjects/UdemyProjects/App7-weather-api/venv/lib/python3.11/site-packages/pandas/core/indexes/base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~/PycharmProjects/UdemyProjects/App7-weather-api/venv/lib/python3.11/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/PycharmProjects/UdemyProjects/App7-weather-api/venv/lib/python3.11/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '   DATE'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 df.loc[df["   DATE"]=="1860-01-05"]["   TG"]
#
# File ~/PycharmProjects/UdemyProjects/App7-weather-api/venv/lib/python3.11/site-packages/pandas/core/frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File ~/PycharmProjects/UdemyProjects/App7-weather-api/venv/lib/python3.11/site-packages/pandas/core/indexes/base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: '   DATE'

# %%
df.loc[df['   TG']==df["   TG"].max()]
# Out:
#       STAID   SOUID       DATE     TG   Q_TG
# 3150      1   35381 1868-08-16    262      0

# %% [markdown]
# # calculate a new column out of an existing column

# %%
import numpy as np
df["TG0"] = df['   TG'].mask(df['   TG'] == -9999, np.nan)
df
# Out:
#        STAID   SOUID       DATE     TG   Q_TG     TG  Fahrenheit   TG0
# 0          1   35381 1860-01-01     21      0    2.1       35.78  21.0
# 1          1   35381 1860-01-02     46      0    4.6       40.28  46.0
# 2          1   35381 1860-01-03     31      0    3.1       37.58  31.0
# 3          1   35381 1860-01-04     37      0    3.7       38.66  37.0
# 4          1   35381 1860-01-05     31      0    3.1       37.58  31.0
# ...      ...     ...        ...    ...    ...    ...         ...   ...
# 59316      1   35381 2022-05-27  -9999      9 -999.9    -1767.82   NaN
# 59317      1   35381 2022-05-28  -9999      9 -999.9    -1767.82   NaN
# 59318      1   35381 2022-05-29  -9999      9 -999.9    -1767.82   NaN
# 59319      1   35381 2022-05-30  -9999      9 -999.9    -1767.82   NaN
# 59320      1   35381 2022-05-31  -9999      9 -999.9    -1767.82   NaN
#
# [59321 rows x 8 columns]

# %%
df["TG"] = df["TG0"]/10

# %%
df
# Out:
#        STAID   SOUID       DATE     TG   Q_TG   TG  Fahrenheit   TG0
# 0          1   35381 1860-01-01     21      0  2.1       35.78  21.0
# 1          1   35381 1860-01-02     46      0  4.6       40.28  46.0
# 2          1   35381 1860-01-03     31      0  3.1       37.58  31.0
# 3          1   35381 1860-01-04     37      0  3.7       38.66  37.0
# 4          1   35381 1860-01-05     31      0  3.1       37.58  31.0
# ...      ...     ...        ...    ...    ...  ...         ...   ...
# 59316      1   35381 2022-05-27  -9999      9  NaN    -1767.82   NaN
# 59317      1   35381 2022-05-28  -9999      9  NaN    -1767.82   NaN
# 59318      1   35381 2022-05-29  -9999      9  NaN    -1767.82   NaN
# 59319      1   35381 2022-05-30  -9999      9  NaN    -1767.82   NaN
# 59320      1   35381 2022-05-31  -9999      9  NaN    -1767.82   NaN
#
# [59321 rows x 8 columns]

# %%
df["Fahrenheit"] = df["TG"]*(9/5) + 32

# %%
df
# Out:
#        STAID   SOUID       DATE     TG   Q_TG     TG  Fahrenheit
# 0          1   35381 1860-01-01     21      0    2.1       35.78
# 1          1   35381 1860-01-02     46      0    4.6       40.28
# 2          1   35381 1860-01-03     31      0    3.1       37.58
# 3          1   35381 1860-01-04     37      0    3.7       38.66
# 4          1   35381 1860-01-05     31      0    3.1       37.58
# ...      ...     ...        ...    ...    ...    ...         ...
# 59316      1   35381 2022-05-27  -9999      9 -999.9    -1767.82
# 59317      1   35381 2022-05-28  -9999      9 -999.9    -1767.82
# 59318      1   35381 2022-05-29  -9999      9 -999.9    -1767.82
# 59319      1   35381 2022-05-30  -9999      9 -999.9    -1767.82
# 59320      1   35381 2022-05-31  -9999      9 -999.9    -1767.82
#
# [59321 rows x 7 columns]

# %% [markdown]
# # plotting

# %%
df["Fahrenheit"].hist()
# Out:
# <Axes: >

# %%
df.plot(x="   DATE", y="TG", figsize=(15, 3))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/PycharmProjects/UdemyProjects/App7-weather-api/venv/lib/python3.11/site-packages/pandas/core/indexes/base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~/PycharmProjects/UdemyProjects/App7-weather-api/venv/lib/python3.11/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/PycharmProjects/UdemyProjects/App7-weather-api/venv/lib/python3.11/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '   DATE'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 df.plot(x="   DATE", y="TG", figsize=(15, 3))
#
# File ~/PycharmProjects/UdemyProjects/App7-weather-api/venv/lib/python3.11/site-packages/pandas/plotting/_core.py:940, in PlotAccessor.__call__(self, *args, **kwargs)
#     938 if is_integer(x) and not data.columns._holds_integer():
#     939     x = data_cols[x]
# --> 940 elif not isinstance(data[x], ABCSeries):
#     941     raise ValueError("x must be a label or position")
#     942 data = data.set_index(x)
#
# File ~/PycharmProjects/UdemyProjects/App7-weather-api/venv/lib/python3.11/site-packages/pandas/core/frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File ~/PycharmProjects/UdemyProjects/App7-weather-api/venv/lib/python3.11/site-packages/pandas/core/indexes/base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: '   DATE'
